# %%
from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import audioFeatureExtraction as aF
from pyAudioAnalysis import audioTrainTest as aT

# %%
import os
import glob
import ntpath
import numpy as np

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #  ========================================================
# # 1. RAVDESS
# #  ========================================================

# %%
os.chdir(r"\Users\preranasingh\Documents\Documents - Prerana’s MacBook Pro\sem3\human computational behaviour\project\Project\data\RAVDESS")

# %% [markdown]
# ## (I) Complete

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  SVM
# ###  ========================================================

# %% [markdown]
# #### a) Training with crossvalidation on complete dataset

# %%
aT.featureAndTrain(['angry', 'calm', 'disgust', 'fearful',
                    'happy', 'neutral', 'sad', 'surprised'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svmEmotion", False)
# Out:
# Feature extraction complexity ratio: 46.7 x realtime
# Feature extraction complexity ratio: 46.0 x realtime
# Feature extraction complexity ratio: 46.9 x realtime
# Feature extraction complexity ratio: 46.0 x realtime
# Feature extraction complexity ratio: 47.8 x realtime
# Feature extraction complexity ratio: 49.0 x realtime
# Feature extraction complexity ratio: 46.1 x realtime
# Feature extraction complexity ratio: 42.1 x realtime
# Number of training experiments changed to 50 due to high number of samples
# Param = 0.00100 - Classifier Evaluation Experiment 1 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 2 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 3 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 4 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 5 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 6 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 7 of 50
# ...

# %% [markdown]
# #### b) Training on male audio samples

# %%
aT.featureAndTrain(['angry male', 'calm male', 'disgust male', 'fearful male',
                    'happy male', 'neutral male', 'sad male', 'surprised male'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svmEmotion_Male", False)
# Out:
# Feature extraction complexity ratio: 75.9 x realtime
# Feature extraction complexity ratio: 75.9 x realtime
# Feature extraction complexity ratio: 71.3 x realtime
# Feature extraction complexity ratio: 76.1 x realtime
# Feature extraction complexity ratio: 65.4 x realtime
# Feature extraction complexity ratio: 59.4 x realtime
# Feature extraction complexity ratio: 76.3 x realtime
# Feature extraction complexity ratio: 78.2 x realtime
# Param = 0.00100 - Classifier Evaluation Experiment 1 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 2 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 3 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 4 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 5 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 6 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 7 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 8 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 9 of 100
# ...

# %% [markdown]
# #### c) Training on female audio samples

# %%
aT.featureAndTrain(["angry female", "calm female", "disgust female", "fearful female",
                    "happy female", "neutral female", "sad female", "surprised female"],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svmEmotion_Female", False)
# Out:
# Feature extraction complexity ratio: 42.9 x realtime
# Feature extraction complexity ratio: 47.3 x realtime
# Feature extraction complexity ratio: 48.8 x realtime
# Feature extraction complexity ratio: 41.6 x realtime
# Feature extraction complexity ratio: 43.5 x realtime
# Feature extraction complexity ratio: 38.6 x realtime
# Feature extraction complexity ratio: 44.7 x realtime
# Feature extraction complexity ratio: 44.0 x realtime
# Param = 0.00100 - Classifier Evaluation Experiment 1 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 2 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 3 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 4 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 5 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 6 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 7 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 8 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 9 of 100
# ...

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  Random Forrest
# ###  ========================================================

# %% [markdown]
# #### a) Training with crossvalidation on complete dataset

# %%
aT.featureAndTrain(['angry', 'calm', 'disgust', 'fearful',
                    'happy', 'neutral', 'sad', 'surprised'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "randomforest", "randomforestEmotion", False)
# Out:
# Feature extraction complexity ratio: 77.6 x realtime
# Feature extraction complexity ratio: 75.8 x realtime
# Feature extraction complexity ratio: 77.6 x realtime
# Feature extraction complexity ratio: 72.5 x realtime
# Feature extraction complexity ratio: 74.5 x realtime
# Feature extraction complexity ratio: 77.8 x realtime
# Feature extraction complexity ratio: 77.8 x realtime
# Feature extraction complexity ratio: 76.9 x realtime
# Number of training experiments changed to 50 due to high number of samples
# Param = 10.00000 - Classifier Evaluation Experiment 1 of 50
# Param = 10.00000 - Classifier Evaluation Experiment 2 of 50
# Param = 10.00000 - Classifier Evaluation Experiment 3 of 50
# Param = 10.00000 - Classifier Evaluation Experiment 4 of 50
# Param = 10.00000 - Classifier Evaluation Experiment 5 of 50
# Param = 10.00000 - Classifier Evaluation Experiment 6 of 50
# Param = 10.00000 - Classifier Evaluation Experiment 7 of 50
# ...

# %% [markdown]
# #### b) Training on male audio samples

# %%
aT.featureAndTrain(['angry male', 'calm male', 'disgust male', 'fearful male',
                    'happy male', 'neutral male', 'sad male', 'surprised male'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "randomforest", "rfEmotion_Male", False)
# Out:
# Feature extraction complexity ratio: 78.7 x realtime
# Feature extraction complexity ratio: 79.3 x realtime
# Feature extraction complexity ratio: 79.5 x realtime
# Feature extraction complexity ratio: 76.6 x realtime
# Feature extraction complexity ratio: 78.5 x realtime
# Feature extraction complexity ratio: 78.2 x realtime
# Feature extraction complexity ratio: 78.9 x realtime
# Feature extraction complexity ratio: 76.8 x realtime
# Param = 10.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 8 of 100
# ...

# %% [markdown]
# #### c) Training on female audio samples

# %%
aT.featureAndTrain(["angry female", "calm female", "disgust female", "fearful female",
                    "happy female", "neutral female", "sad female", "surprised female"],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "randomforest", "randomforestEmotion_Female", False)
# Out:
# Feature extraction complexity ratio: 75.0 x realtime
# Feature extraction complexity ratio: 73.6 x realtime
# Feature extraction complexity ratio: 76.4 x realtime
# Feature extraction complexity ratio: 75.0 x realtime
# Feature extraction complexity ratio: 75.9 x realtime
# Feature extraction complexity ratio: 78.0 x realtime
# Feature extraction complexity ratio: 76.3 x realtime
# Feature extraction complexity ratio: 76.4 x realtime
# Param = 10.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 8 of 100
# ...

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  KNN
# ###  ========================================================

# %% [markdown]
# #### a) Training with crossvalidation on complete dataset

# %%
aT.featureAndTrain(['angry', 'calm', 'disgust', 'fearful',
                    'happy', 'neutral', 'sad', 'surprised'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "knn", "knnEmotion", False)
# Out:
# Feature extraction complexity ratio: 79.5 x realtime
# Feature extraction complexity ratio: 79.1 x realtime
# Feature extraction complexity ratio: 78.9 x realtime
# Feature extraction complexity ratio: 79.4 x realtime
# Feature extraction complexity ratio: 79.9 x realtime
# Feature extraction complexity ratio: 79.9 x realtime
# Feature extraction complexity ratio: 80.1 x realtime
# Feature extraction complexity ratio: 79.7 x realtime
# Number of training experiments changed to 50 due to high number of samples
# Param = 1.00000 - Classifier Evaluation Experiment 1 of 50
# Param = 1.00000 - Classifier Evaluation Experiment 2 of 50
# Param = 1.00000 - Classifier Evaluation Experiment 3 of 50
# Param = 1.00000 - Classifier Evaluation Experiment 4 of 50
# Param = 1.00000 - Classifier Evaluation Experiment 5 of 50
# Param = 1.00000 - Classifier Evaluation Experiment 6 of 50
# Param = 1.00000 - Classifier Evaluation Experiment 7 of 50
# ...

# %% [markdown]
# #### b) Training on male audio samples

# %%
aT.featureAndTrain(['angry male', 'calm male', 'disgust male', 'fearful male',
                    'happy male', 'neutral male', 'sad male', 'surprised male'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "knn", "knnEmotion_Male", False)
# Out:
# Feature extraction complexity ratio: 78.4 x realtime
# Feature extraction complexity ratio: 79.6 x realtime
# Feature extraction complexity ratio: 80.1 x realtime
# Feature extraction complexity ratio: 77.4 x realtime
# Feature extraction complexity ratio: 78.1 x realtime
# Feature extraction complexity ratio: 79.2 x realtime
# Feature extraction complexity ratio: 78.3 x realtime
# Feature extraction complexity ratio: 79.5 x realtime
# Param = 1.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 8 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 9 of 100
# ...

# %% [markdown]
# #### c) Training on female audio samples

# %%
aT.featureAndTrain(["angry female", "calm female", "disgust female", "fearful female",
                    "happy female", "neutral female", "sad female", "surprised female"],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "knn", "knnEmotion_Female", False)
# Out:
# Feature extraction complexity ratio: 74.5 x realtime
# Feature extraction complexity ratio: 77.9 x realtime
# Feature extraction complexity ratio: 72.0 x realtime
# Feature extraction complexity ratio: 76.6 x realtime
# Feature extraction complexity ratio: 79.3 x realtime
# Feature extraction complexity ratio: 78.3 x realtime
# Feature extraction complexity ratio: 72.2 x realtime
# Feature extraction complexity ratio: 77.6 x realtime
# Param = 1.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 8 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 9 of 100
# ...

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  MLP Classifier
# ###  ========================================================

# %% [markdown]
# #### a) Complete dataset

# %%
listOfDirs = ['angry', 'calm', 'disgust', 'fearful',
              'happy', 'neutral', 'sad', 'surprised']

[features, classNames, _] = aF.dirsWavFeatureExtraction(listOfDirs, mtWin, mtStep, stWin, stStep, computeBEAT=False)

if len(featuresFemale) == 0:
    print "No data found."
else:
    numOfFeatures = features[0].shape[1]
    featureNames = ["features" + str(d + 1) for d in range(numOfFeatures)]
    aT.writeTrainDataToARFF("RAVDESSAngryFemale", features, classNames, featureNames)
    
X = np.vstack((features[0],features[1],features[2],features[3],
               features[4],features[5],features[6],features[7]))

Y = np.array([])

for i in range(8):
    cls = classNames[i]
    for j in range(len(features[i])):
        Y = np.append(Y, cls)
        
        
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=48, stratify=Y)

clf = MLPClassifier(activation='tanh', alpha=0.03, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(64, 64, 64), learning_rate='constant',
       learning_rate_init=0.001, max_iter=100000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=48, shuffle=True,
       solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
       warm_start=False)


clf.fit(X_train, y_train) 

y_pred = clf.predict(X_test)
# print clf.best_score_
# print clf.best_estimator_
prediction1=clf.predict(X_test)
print('Accuracy', metrics.accuracy_score(prediction1,y_test))
# Out:
# Feature extraction complexity ratio: 52.0 x realtime
# Feature extraction complexity ratio: 82.4 x realtime
# Feature extraction complexity ratio: 78.8 x realtime
# Feature extraction complexity ratio: 78.9 x realtime
# Feature extraction complexity ratio: 73.2 x realtime
# Feature extraction complexity ratio: 75.7 x realtime
# Feature extraction complexity ratio: 73.5 x realtime
# Feature extraction complexity ratio: 76.1 x realtime
# ('Accuracy', 0.3992673992673993)

# %% [markdown]
# #### b) Training on male audio samples

# %%
listOfDirs = ['angry male', 'calm male', 'disgust male', 'fearful male',
            'happy male', 'neutral male', 'sad male', 'surprised male']
mtWin = 1.0
mtStep = 1.0
stWin = aT.shortTermWindow
stStep = aT.shortTermStep


[features, classNames, _] = aF.dirsWavFeatureExtraction(listOfDirs, mtWin, mtStep, stWin, stStep, computeBEAT=False)


if len(features) == 0:
    print "No data found."
else:
    numOfFeatures = features[0].shape[1]
    featureNames = ["features" + str(d + 1) for d in range(numOfFeatures)]
    aT.writeTrainDataToARFF("RAVDESSAngryMale", features, classNames, featureNames)

X = np.vstack((features[0],features[1],features[2],features[3],features[4],features[5],features[6],features[7]))

Y = np.array([])

for i in range(8):
    cls = classNames[i]
    for j in range(len(features[i])):
        Y = np.append(Y, cls)
        
parameters = {'activation':('logistic', 'tanh'),
              'solver':['lbfgs'],
              'alpha':(3e-2, 0.01),
              'learning_rate': ('constant', 'adaptive'),
              'hidden_layer_sizes':( (64, 64, 64), (64, 8, 8) ),              # (10, ), (4, 4), (4, 5, 6), 
              'max_iter':(100, 1000, 10000, 100000),
              'random_state':[48]}


mlp = MLPClassifier()
clf = GridSearchCV(mlp, parameters)
# Out:
# Feature extraction complexity ratio: 82.0 x realtime
# Feature extraction complexity ratio: 79.3 x realtime
# Feature extraction complexity ratio: 70.7 x realtime
# Feature extraction complexity ratio: 72.2 x realtime
# Feature extraction complexity ratio: 80.7 x realtime
# Feature extraction complexity ratio: 62.6 x realtime
# Feature extraction complexity ratio: 70.6 x realtime
# Feature extraction complexity ratio: 69.5 x realtime

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=48, stratify=Y)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
print clf.best_score_
# Out:
# 0.4724137931034483

# %%
print clf.best_estimator_
# Out:
# MLPClassifier(activation='tanh', alpha=0.03, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(64, 64, 64), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=100000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=48, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
prediction1=clf.predict(X_test)
print('Accuracy', metrics.accuracy_score(prediction1,y_test))
# Out:
# ('Accuracy', 0.4827586206896552)

# %% [markdown]
# #### c) Training on female audio samples

# %%
listOfDirs = ['angry female', 'calm female', 'disgust female', 'fearful female',
              'happy female', 'neutral female', 'sad female', 'surprised female']

[featuresFemale, classNamesFemale, _] = aF.dirsWavFeatureExtraction(listOfDirs, mtWin, mtStep, stWin, stStep, computeBEAT=False)
# Out:
# Feature extraction complexity ratio: 79.6 x realtime
# Feature extraction complexity ratio: 80.8 x realtime
# Feature extraction complexity ratio: 80.6 x realtime
# Feature extraction complexity ratio: 80.0 x realtime
# Feature extraction complexity ratio: 80.2 x realtime
# Feature extraction complexity ratio: 70.3 x realtime
# Feature extraction complexity ratio: 68.8 x realtime
# Feature extraction complexity ratio: 66.1 x realtime

# %%
if len(featuresFemale) == 0:
    print "No data found."
else:
    numOfFeatures = featuresFemale[0].shape[1]
    featureNames = ["features" + str(d + 1) for d in range(numOfFeatures)]
    aT.writeTrainDataToARFF("RAVDESSAngryFemale", featuresFemale, classNamesFemale, featureNames)

X = np.vstack((featuresFemale[0],featuresFemale[1],featuresFemale[2],featuresFemale[3],
               featuresFemale[4],featuresFemale[5],featuresFemale[6],featuresFemale[7]))

Y = np.array([])

for i in range(8):
    cls = classNamesFemale[i]
    for j in range(len(featuresFemale[i])):
        Y = np.append(Y, cls)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=48, stratify=Y)

clf = MLPClassifier(activation='tanh', alpha=0.03, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(64, 64, 64), learning_rate='constant',
       learning_rate_init=0.001, max_iter=100000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=48, shuffle=True,
       solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
       warm_start=False)


clf.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='tanh', alpha=0.03, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(64, 64, 64), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=100000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=48, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
y_pred = clf.predict(X_test)
# print clf.best_score_
# print clf.best_estimator_
prediction1=clf.predict(X_test)
print('Accuracy', metrics.accuracy_score(prediction1,y_test))
# Out:
# ('Accuracy', 0.515625)

# %% [markdown]
# ## (II) Subset

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  SVM
# ###  ========================================================

# %% [markdown]
# #### a) Training with crossvalidation on complete dataset

# %%
aT.featureAndTrain(['angry','happy', 'neutral', 'sad'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svmEmotion_ang_sad_hap_neu", False)
# Out:
# Feature extraction complexity ratio: 71.4 x realtime
# Feature extraction complexity ratio: 75.2 x realtime
# Feature extraction complexity ratio: 70.8 x realtime
# Feature extraction complexity ratio: 73.8 x realtime
# Param = 0.00100 - Classifier Evaluation Experiment 1 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 2 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 3 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 4 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 5 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 6 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 7 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 8 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 9 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 10 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 11 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 12 of 100
# ...

# %% [markdown]
# #### b) Training on male audio samples

# %%
aT.featureAndTrain(['angry male', 'happy male',
                    'neutral male', 'sad male'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svmEmotion_Male_ang_sad_hap_neu", False)
# Out:
# Feature extraction complexity ratio: 51.3 x realtime
# Feature extraction complexity ratio: 49.3 x realtime
# Feature extraction complexity ratio: 49.9 x realtime
# Feature extraction complexity ratio: 49.9 x realtime
# Param = 0.00100 - Classifier Evaluation Experiment 1 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 2 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 3 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 4 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 5 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 6 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 7 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 8 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 9 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 10 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 11 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 12 of 100
# ...

# %% [markdown]
# #### c) Training on female audio samples

# %%
aT.featureAndTrain(['angry female','happy female',
                    'neutral female', 'sad female'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svmEmotion_Female_ang_sad_hap_neu", False)
# Out:
# Feature extraction complexity ratio: 77.7 x realtime
# Feature extraction complexity ratio: 74.3 x realtime
# Feature extraction complexity ratio: 74.9 x realtime
# Feature extraction complexity ratio: 75.7 x realtime
# Param = 0.00100 - Classifier Evaluation Experiment 1 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 2 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 3 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 4 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 5 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 6 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 7 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 8 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 9 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 10 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 11 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 12 of 100
# ...

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  Random Forest
# ###  ========================================================

# %% [markdown]
# #### a) Training with crossvalidation on complete dataset

# %%
aT.featureAndTrain(['angry', 'happy',
                    'neutral', 'sad'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "randomforest", "rfEmotion_ang_sad_hap_neu", False)
# Out:
# Feature extraction complexity ratio: 79.1 x realtime
# Feature extraction complexity ratio: 78.0 x realtime
# Feature extraction complexity ratio: 74.6 x realtime
# Feature extraction complexity ratio: 77.2 x realtime
# Param = 10.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 8 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 9 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 10 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 11 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 12 of 100
# ...

# %% [markdown]
# #### b) Training on male audio samples

# %%
aT.featureAndTrain(['angry male', 'happy male', 'neutral male', 'sad male'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "randomforest", "rfEmotion_Male_ang_sad_hap_neu", False)
# Out:
# Feature extraction complexity ratio: 77.0 x realtime
# Feature extraction complexity ratio: 77.9 x realtime
# Feature extraction complexity ratio: 76.7 x realtime
# Feature extraction complexity ratio: 75.1 x realtime
# Param = 10.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 8 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 9 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 10 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 11 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 12 of 100
# ...

# %% [markdown]
# #### c) Training on female audio samples

# %%
aT.featureAndTrain(['angry female', 'happy female', 'neutral female', 'sad female'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "randomforest", "rfEmotion_Female_ang_sad_hap_neu", False)
# Out:
# Feature extraction complexity ratio: 78.3 x realtime
# Feature extraction complexity ratio: 79.9 x realtime
# Feature extraction complexity ratio: 79.7 x realtime
# Feature extraction complexity ratio: 79.9 x realtime
# Param = 10.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 8 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 9 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 10 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 11 of 100
# Param = 10.00000 - Classifier Evaluation Experiment 12 of 100
# ...

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  KNN
# ###  ========================================================

# %% [markdown]
# #### a) Training with crossvalidation on complete dataset

# %%
aT.featureAndTrain(['angry', 'happy', 'neutral', 'sad'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "knn", "knnEmotion_ang_sad_hap_neu", False)
# Out:
# Feature extraction complexity ratio: 77.8 x realtime
# Feature extraction complexity ratio: 74.0 x realtime
# Feature extraction complexity ratio: 76.5 x realtime
# Feature extraction complexity ratio: 78.3 x realtime
# Param = 1.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 8 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 9 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 10 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 11 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 12 of 100
# ...

# %% [markdown]
# #### b) Training on male audio samples

# %%
aT.featureAndTrain(['angry male', 'happy male',
                    'neutral male', 'sad male'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "knn", "knnEmotion_Male_ang_sad_hap_neu", False)
# Out:
# Feature extraction complexity ratio: 79.5 x realtime
# Feature extraction complexity ratio: 80.4 x realtime
# Feature extraction complexity ratio: 79.7 x realtime
# Feature extraction complexity ratio: 80.2 x realtime
# Param = 1.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 8 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 9 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 10 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 11 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 12 of 100
# ...

# %% [markdown]
# #### c) Training on female audio samples

# %%
aT.featureAndTrain(['angry female', 'happy female',
                    'neutral female', 'sad female'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "knn", "knnEmotion_Female_ang_sad_hap_neu", False)
# Out:
# Feature extraction complexity ratio: 78.5 x realtime
# Feature extraction complexity ratio: 79.3 x realtime
# Feature extraction complexity ratio: 80.6 x realtime
# Feature extraction complexity ratio: 80.6 x realtime
# Param = 1.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 8 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 9 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 10 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 11 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 12 of 100
# ...

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  MLP Classifier
# ###  ========================================================

# %% [markdown]
# #### a) Training with crossvalidation on complete dataset

# %%
listOfDirs = ['angry', 'happy',
              'neutral', 'sad']

[features, classNames, _] = aF.dirsWavFeatureExtraction(listOfDirs, mtWin, mtStep, stWin, stStep, computeBEAT=False)

if len(featuresFemale) == 0:
    print "No data found."
else:
    numOfFeatures = features[0].shape[1]
    featureNames = ["features" + str(d + 1) for d in range(numOfFeatures)]
    aT.writeTrainDataToARFF("RAVDESS_subset", features, classNames, featureNames)
    
X = np.vstack((features[0],features[1],features[2],features[3]))

Y = np.array([])

for i in range(4):
    cls = classNames[i]
    for j in range(len(features[i])):
        Y = np.append(Y, cls)
        
        
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=48, stratify=Y)

clf = MLPClassifier(activation='tanh', alpha=0.03, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(64, 64, 64), learning_rate='constant',
       learning_rate_init=0.001, max_iter=100000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=48, shuffle=True,
       solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
       warm_start=False)


clf.fit(X_train, y_train) 

y_pred = clf.predict(X_test)
# print clf.best_score_
# print clf.best_estimator_
prediction1=clf.predict(X_test)
print('Accuracy', metrics.accuracy_score(prediction1,y_test))
# Out:
# Feature extraction complexity ratio: 78.1 x realtime
# Feature extraction complexity ratio: 81.8 x realtime
# Feature extraction complexity ratio: 80.8 x realtime
# Feature extraction complexity ratio: 80.9 x realtime
# ('Accuracy', 0.5966386554621849)

# %% [markdown]
# #### b) Training on male audio samples

# %%
listOfDirs = ['angry male', 'happy male',
              'neutral male', 'sad male']

[features, classNames, _] = aF.dirsWavFeatureExtraction(listOfDirs, mtWin, mtStep, stWin, stStep, computeBEAT=False)

if len(featuresFemale) == 0:
    print "No data found."
else:
    numOfFeatures = features[0].shape[1]
    featureNames = ["features" + str(d + 1) for d in range(numOfFeatures)]
    aT.writeTrainDataToARFF("RAVDESS_subset_male", features, classNames, featureNames)
    
X = np.vstack((features[0],features[1],features[2],features[3]))

Y = np.array([])

for i in range(4):
    cls = classNames[i]
    for j in range(len(features[i])):
        Y = np.append(Y, cls)
        
        
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=48, stratify=Y)

clf = MLPClassifier(activation='tanh', alpha=0.03, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(64, 64, 64), learning_rate='constant',
       learning_rate_init=0.001, max_iter=100000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=48, shuffle=True,
       solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
       warm_start=False)


clf.fit(X_train, y_train) 

y_pred = clf.predict(X_test)
# print clf.best_score_
# print clf.best_estimator_
prediction1=clf.predict(X_test)
print('Accuracy', metrics.accuracy_score(prediction1,y_test))
# Out:
# Feature extraction complexity ratio: 79.3 x realtime
# Feature extraction complexity ratio: 82.5 x realtime
# Feature extraction complexity ratio: 81.7 x realtime
# Feature extraction complexity ratio: 80.4 x realtime
# ('Accuracy', 0.6376811594202898)

# %% [markdown]
# #### c) Training on female audio samples

# %%
listOfDirs = ['angry female', 'happy female',
              'neutral female', 'sad female']

[features, classNames, _] = aF.dirsWavFeatureExtraction(listOfDirs, mtWin, mtStep, stWin, stStep, computeBEAT=False)

if len(featuresFemale) == 0:
    print "No data found."
else:
    numOfFeatures = features[0].shape[1]
    featureNames = ["features" + str(d + 1) for d in range(numOfFeatures)]
    aT.writeTrainDataToARFF("RAVDESS_subset", features, classNames, featureNames)
    
X = np.vstack((features[0],features[1],features[2],features[3]))

Y = np.array([])

for i in range(4):
    cls = classNames[i]
    for j in range(len(features[i])):
        Y = np.append(Y, cls)
        
        
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=48, stratify=Y)

clf = MLPClassifier(activation='tanh', alpha=0.03, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(64, 64, 64), learning_rate='constant',
       learning_rate_init=0.001, max_iter=100000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=48, shuffle=True,
       solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
       warm_start=False)


clf.fit(X_train, y_train) 

y_pred = clf.predict(X_test)
# print clf.best_score_
# print clf.best_estimator_
prediction1=clf.predict(X_test)
print('Accuracy', metrics.accuracy_score(prediction1,y_test))
# Out:
# Feature extraction complexity ratio: 59.5 x realtime
# Feature extraction complexity ratio: 68.6 x realtime
# Feature extraction complexity ratio: 81.5 x realtime
# Feature extraction complexity ratio: 78.3 x realtime
# ('Accuracy', 0.6862745098039216)

# %% [markdown]
# #  ========================================================
# # 2. Consolidated RAVDESS + BDES + SAVEE
# #  ========================================================

# %%
os.chdir(r"\Users\preranasingh\Documents\Documents - Prerana’s MacBook Pro\sem3\human computational behaviour\project\Project\data\R_B_S")

# %% [markdown]
# ## (I) Complete

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  SVM
# ###  ========================================================

# %%
aT.featureAndTrain(['angry', 'disgust', 'fearful',
                    'happy', 'neutral', 'sad'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svmEmotion_RBS", False)
# Out:
# Feature extraction complexity ratio: 66.9 x realtime
# Feature extraction complexity ratio: 56.0 x realtime
# Feature extraction complexity ratio: 56.1 x realtime
# Feature extraction complexity ratio: 56.9 x realtime
# Feature extraction complexity ratio: 57.1 x realtime
# Feature extraction complexity ratio: 55.9 x realtime
# Number of training experiments changed to 50 due to high number of samples
# Param = 0.00100 - Classifier Evaluation Experiment 1 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 2 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 3 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 4 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 5 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 6 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 7 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 8 of 50
# Param = 0.00100 - Classifier Evaluation Experiment 9 of 50
# ...

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  KNN
# ###  ========================================================

# %%
aT.featureAndTrain(['angry', 'disgust', 'fearful',
                    'happy', 'neutral', 'sad'],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "knn", "knnEmotion_RBS", False)
# Out:
# Feature extraction complexity ratio: 86.2 x realtime
# Feature extraction complexity ratio: 83.5 x realtime
# Feature extraction complexity ratio: 84.9 x realtime
# Feature extraction complexity ratio: 88.6 x realtime
# Feature extraction complexity ratio: 88.1 x realtime
# Feature extraction complexity ratio: 80.2 x realtime
# Param = 1.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 8 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 9 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 10 of 100
# ...

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  MLP Classifier
# ###  ========================================================

# %%
listOfDirs = ['angry', 'disgust', 'fearful', 'happy', 'neutral', 'sad']

[features, classNames, _] = aF.dirsWavFeatureExtraction(listOfDirs, mtWin, mtStep, stWin, stStep, computeBEAT=False)

if len(featuresFemale) == 0:
    print "No data found."
else:
    numOfFeatures = features[0].shape[1]
    featureNames = ["features" + str(d + 1) for d in range(numOfFeatures)]
    aT.writeTrainDataToARFF("RAVDESS_subset", features, classNames, featureNames)
    
X = np.vstack((features[0],features[1],features[2],features[3]))

Y = np.array([])

for i in range(4):
    cls = classNames[i]
    for j in range(len(features[i])):
        Y = np.append(Y, cls)
        
        
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=48, stratify=Y)

clf = MLPClassifier(activation='tanh', alpha=0.03, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(64, 64, 64), learning_rate='constant',
       learning_rate_init=0.001, max_iter=100000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=48, shuffle=True,
       solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
       warm_start=False)


clf.fit(X_train, y_train) 

y_pred = clf.predict(X_test)
# print clf.best_score_
# print clf.best_estimator_
prediction1=clf.predict(X_test)
print('Accuracy', metrics.accuracy_score(prediction1,y_test))
# Out:
# Feature extraction complexity ratio: 80.6 x realtime
# Feature extraction complexity ratio: 77.9 x realtime
# Feature extraction complexity ratio: 73.8 x realtime
# Feature extraction complexity ratio: 93.7 x realtime
# Feature extraction complexity ratio: 78.3 x realtime
# Feature extraction complexity ratio: 94.0 x realtime
# ('Accuracy', 0.5405405405405406)

# %% [markdown]
# ## (II) Subset

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  SVM
# ###  ========================================================

# %%
aT.featureAndTrain( ['angry', 'happy',
                     'neutral', 'sad',],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svmEmotion_RBS_sub", False)
# Out:
# Feature extraction complexity ratio: 90.0 x realtime
# Feature extraction complexity ratio: 72.7 x realtime
# Feature extraction complexity ratio: 82.2 x realtime
# Feature extraction complexity ratio: 78.7 x realtime
# Param = 0.00100 - Classifier Evaluation Experiment 1 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 2 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 3 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 4 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 5 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 6 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 7 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 8 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 9 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 10 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 11 of 100
# Param = 0.00100 - Classifier Evaluation Experiment 12 of 100
# ...

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  KNN
# ###  ========================================================

# %%
aT.featureAndTrain(['angry', 'happy',
                    'neutral', 'sad',],
                   1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "knn", "knnEmotion_RBS_sub", False)
# Out:
# Feature extraction complexity ratio: 94.7 x realtime
# Feature extraction complexity ratio: 91.1 x realtime
# Feature extraction complexity ratio: 78.0 x realtime
# Feature extraction complexity ratio: 90.9 x realtime
# Param = 1.00000 - Classifier Evaluation Experiment 1 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 2 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 3 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 4 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 5 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 6 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 7 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 8 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 9 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 10 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 11 of 100
# Param = 1.00000 - Classifier Evaluation Experiment 12 of 100
# ...

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------
# ###  MLP Classifier
# ###  ========================================================

# %%
listOfDirs =  ['angry', 'happy',
               'neutral', 'sad',]

[features, classNames, _] = aF.dirsWavFeatureExtraction(listOfDirs, mtWin, mtStep, stWin, stStep, computeBEAT=False)

if len(featuresFemale) == 0:
    print "No data found."
else:
    numOfFeatures = features[0].shape[1]
    featureNames = ["features" + str(d + 1) for d in range(numOfFeatures)]
    aT.writeTrainDataToARFF("RBS_subset", features, classNames, featureNames)
    
X = np.vstack((features[0],features[1],features[2],features[3]))

Y = np.array([])

for i in range(4):
    cls = classNames[i]
    for j in range(len(features[i])):
        Y = np.append(Y, cls)
        
        
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=48, stratify=Y)

clf = MLPClassifier(activation='tanh', alpha=0.03, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(64, 64, 64), learning_rate='constant',
       learning_rate_init=0.001, max_iter=100000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=48, shuffle=True,
       solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
       warm_start=False)


clf.fit(X_train, y_train) 

y_pred = clf.predict(X_test)
# print clf.best_score_
# print clf.best_estimator_
prediction1=clf.predict(X_test)
print('Accuracy', metrics.accuracy_score(prediction1,y_test))
# Out:
# Feature extraction complexity ratio: 86.0 x realtime
# Feature extraction complexity ratio: 86.9 x realtime
# Feature extraction complexity ratio: 86.5 x realtime
# Feature extraction complexity ratio: 89.6 x realtime
# ('Accuracy', 0.7578125)
